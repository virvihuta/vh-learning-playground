# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 100
D = 2
K = 3
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N)
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2
  X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y[ix] = j
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
import torch

device = 'mps' if torch.backends.mps.is_available() else 'cpu'
device
# Out:
# 'mps'

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
X_test = torch.tensor(X_test, dtype=torch.float32).to(device)
y_train = torch.tensor(y_train, dtype=torch.float32).to(device)
y_test = torch.tensor(y_test, dtype=torch.float32).to(device)

# %%
import torch.nn as nn

class NeuralNetwork01(nn.Module):
    def __init__(self, input, hidden, output):
        super().__init__()
        self.layer = nn.Sequential(
            nn.Linear(in_features=input, out_features=hidden),
            nn.ReLU(),
            nn.Linear(in_features=hidden, out_features=hidden),
            nn.ReLU(),
            nn.Linear(in_features=hidden, out_features=output)
        )

    def forward(self, x):
        return self.layer(x)
    
model_01 = NeuralNetwork01(input=X_train.shape[1], hidden=32, output=3).to(device)
model_01
# Out:
# NeuralNetwork01(
#   (layer): Sequential(
#     (0): Linear(in_features=2, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=3, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_01.parameters(), lr=0.001)

# %%
from helper_functions import accuracy_fn, plot_decision_boundary
torch.manual_seed(42)

epochs = 1000

for epoch in range(epochs):
    model_01.train()
    y_logits = model_01(X_train)
    loss_train = criterion(y_logits, y_train)
    y_preds = torch.softmax(y_logits, dim=1).argmax(dim=1)
    accuracy_train = accuracy_fn(y_train, y_preds)
    optimizer.zero_grad()
    loss_train.backward()
    optimizer.step()

    with torch.inference_mode():
        model_01.eval()
        y_logits = model_01(X_test)
        loss_test = criterion(y_logits, y_test)
        y_preds = torch.softmax(y_logits, dim=1).argmax(dim=1)
        accuracy_test = accuracy_fn(y_test, y_preds)

    if epoch % 10 == 0:
        print(f'Epoch: {epoch} | Training Loss: {loss_train:.2f} | Testing Loss: {loss_test:.2f} | Training Accuracy: {accuracy_train:.2f} | Testing Accuracy: {accuracy_test:.2f}')

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title('Train')
plot_decision_boundary(model_01, X_train, y_train)
plt.subplot(1,2,2)
plt.title('Test')
plot_decision_boundary(model_01, X_test, y_test)
# Out:
# Epoch: 0 | Training Loss: 1.11 | Testing Loss: 1.10 | Training Accuracy: 33.33 | Testing Accuracy: 33.33
# Epoch: 10 | Training Loss: 1.08 | Testing Loss: 1.08 | Training Accuracy: 33.33 | Testing Accuracy: 33.33
# Epoch: 20 | Training Loss: 1.05 | Testing Loss: 1.05 | Training Accuracy: 56.25 | Testing Accuracy: 60.00
# Epoch: 30 | Training Loss: 1.03 | Testing Loss: 1.03 | Training Accuracy: 60.83 | Testing Accuracy: 65.00
# Epoch: 40 | Training Loss: 1.00 | Testing Loss: 1.00 | Training Accuracy: 63.33 | Testing Accuracy: 63.33
# Epoch: 50 | Training Loss: 0.97 | Testing Loss: 0.97 | Training Accuracy: 65.00 | Testing Accuracy: 63.33
# Epoch: 60 | Training Loss: 0.93 | Testing Loss: 0.94 | Training Accuracy: 61.67 | Testing Accuracy: 60.00
# Epoch: 70 | Training Loss: 0.89 | Testing Loss: 0.90 | Training Accuracy: 60.83 | Testing Accuracy: 60.00
# Epoch: 760 | Training Loss: 0.08 | Testing Loss: 0.12 | Training Accuracy: 99.58 | Testing Accuracy: 96.67
# Epoch: 770 | Training Loss: 0.08 | Testing Loss: 0.11 | Training Accuracy: 99.58 | Testing Accuracy: 96.67
# Epoch: 780 | Training Loss: 0.07 | Testing Loss: 0.11 | Training Accuracy: 99.58 | Testing Accuracy: 96.67
# Epoch: 790 | Training Loss: 0.07 | Testing Loss: 0.11 | Training Accuracy: 99.58 | Testing Accuracy: 96.67
# Epoch: 800 | Training Loss: 0.07 | Testing Loss: 0.11 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 810 | Training Loss: 0.07 | Testing Loss: 0.11 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 820 | Training Loss: 0.07 | Testing Loss: 0.11 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 830 | Training Loss: 0.07 | Testing Loss: 0.11 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 840 | Training Loss: 0.06 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 850 | Training Loss: 0.06 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 860 | Training Loss: 0.06 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 870 | Training Loss: 0.06 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 880 | Training Loss: 0.06 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 890 | Training Loss: 0.06 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 900 | Training Loss: 0.06 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 910 | Training Loss: 0.06 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 920 | Training Loss: 0.06 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 930 | Training Loss: 0.05 | Testing Loss: 0.10 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 940 | Training Loss: 0.05 | Testing Loss: 0.09 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 950 | Training Loss: 0.05 | Testing Loss: 0.09 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 960 | Training Loss: 0.05 | Testing Loss: 0.09 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 970 | Training Loss: 0.05 | Testing Loss: 0.09 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 980 | Training Loss: 0.05 | Testing Loss: 0.09 | Training Accuracy: 99.58 | Testing Accuracy: 98.33
# Epoch: 990 | Training Loss: 0.05 | Testing Loss: 0.09 | Training Accuracy: 99.58 | Testing Accuracy: 98.33

# %%
model_01.state_dict()
# Out:
# OrderedDict([('layer.0.weight',
#               tensor([[ 0.3416,  1.5236],
#                       [-0.9578,  1.0820],
#                       [-0.5711,  0.7196],
#                       [-0.7588,  0.9956],
#                       [ 1.5318, -1.3648],
#                       [ 1.3714,  0.4026],
#                       [ 0.9320,  0.8283],
#                       [ 0.6453, -0.5902],
#                       [ 0.9296,  0.9326],
#                       [-0.3301,  0.1802],
#                       [-0.3258, -0.0829],
#                       [-0.2872,  0.4691],
#                       [-1.6561, -1.2665],
#                       [-0.4059, -1.1417],
#                       [ 0.5659, -1.2975],
#                       [ 1.2120, -1.2210],
#                       [ 1.3262, -0.0440],
#                       [-0.2192,  0.4266],
#                       [-0.2812,  1.1323],
#                       [ 0.0773, -0.2230],
#                       [ 0.5860, -0.5885],
#                       [ 1.0086,  0.9819],
#                       [ 0.7934, -0.5944],
#                       [ 0.4082,  0.1265],
#                       [ 1.1542, -0.8920],
#                       [-1.4869, -1.2452],
#                       [-1.3049,  1.2166],
#                       [ 0.9269,  0.7638],
#                       [ 0.7607, -0.1457],
#                       [ 0.9056, -0.8568],
#                       [ 0.0445, -0.4826],
#                       [ 0.2180, -0.2435]])),
#              ('layer.0.bias',
#               tensor([ 0.1399, -0.0672,  1.1447, -0.3443, -0.2246, -0.2661,  1.2387,  0.6461,
#                        1.2684, -0.5836, -0.7014, -0.5532, -0.2661,  0.2100,  0.4236,  0.6611,
#                       -0.1320, -0.4924,  0.8597, -0.2858,  0.6055, -0.2321,  0.7656, -0.5494,
#                       -0.1906,  0.4987,  0.4913, -0.2522,  0.5796,  0.7691, -0.5128, -0.3775])),
#              ('layer.2.weight',
#               tensor([[ 1.6187e-01, -5.9650e-02, -6.2670e-02,  ..., -1.0313e-01,
#                        -6.0510e-02, -1.3953e-01],
#                       [ 1.1933e-01,  4.8720e-01,  4.0756e-01,  ..., -4.4830e-01,
#                         5.7445e-02, -9.5574e-02],
#                       [-4.5285e-01,  3.9477e-01,  2.1611e-01,  ..., -8.5032e-02,
#                        -3.1228e-02, -5.2680e-02],
#                       ...,
#                       [ 4.2669e-01, -2.5281e-01,  6.5665e-01,  ..., -4.0585e-01,
#                         1.7402e-01,  8.5137e-06],
#                       [-3.9919e-01, -1.0725e+00, -7.5180e-01,  ...,  6.9570e-01,
#                         1.6100e-01,  1.0316e-01],
#                       [-5.6906e-01,  3.0992e-01,  2.5555e-01,  ...,  1.0860e-01,
#                         1.0580e-01,  6.2405e-02]])),
#              ('layer.2.bias',
#               tensor([-0.0904, -0.1837,  0.1932, -0.0831,  0.1046,  0.2374,  0.3745,  0.1433,
#                        0.2591,  0.0519, -0.1872,  0.3852, -0.0523, -0.1787,  0.0727,  0.0759,
#                        0.0862,  0.3565, -0.0364,  0.0616,  0.1977,  0.2729,  0.0393, -0.1608,
#                        0.0203,  0.3688, -0.1039, -0.1680,  0.2830,  0.3294, -0.5380,  0.2643])),
#              ('layer.4.weight',
#               tensor([[ 0.0533, -0.3419, -0.5214, -1.2769,  0.1406,  0.8581, -0.8361,  0.1360,
#                        -0.3891,  0.5928,  0.1406,  0.5171, -0.1224,  0.1445, -0.1516,  0.3045,
#                        -0.3328, -0.5676, -0.9248,  0.5338,  0.2418,  0.2124,  0.7372, -1.1130,
#                         0.5982,  1.0462,  0.1300, -0.0141, -0.5329,  0.5346,  0.7298, -0.7277],
#                       [ 0.0217, -0.5820,  0.5443, -0.4126, -0.0057,  0.4523,  0.7363,  0.1160,
#                         0.7716, -0.7889, -0.1365, -0.6544, -0.0861, -0.0586, -0.3833, -0.5173,
#                        -0.6043, -0.4951, -0.5252,  0.5589, -0.5349, -0.7027, -0.5838, -0.3695,
#                         0.1596,  0.4190,  0.1540, -0.1235,  0.7251,  0.5638, -0.7022,  0.7632],
#                       [ 0.1325,  0.5344, -0.6969,  0.6344, -0.1226, -0.6121,  0.6534, -0.0901,
#                        -0.5109,  0.7396,  0.1488,  0.7973,  0.0296, -0.1211,  0.3524,  0.7581,
#                         0.4430,  0.5563,  0.6948, -0.6626,  0.6108,  0.4825, -0.2722,  0.9923,
#                        -0.6087, -0.5778,  0.0411, -0.0528,  0.5378, -0.6766, -1.0801,  0.2994]])),
#              ('layer.4.bias', tensor([-0.0753, -0.0739,  0.1061]))])
